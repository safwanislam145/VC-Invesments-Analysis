# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# %% [markdown]
# # LOADING AND EXPLORING DATA

# %%
# load the data 

data = pd.read_csv('data.csv', encoding='latin1')
data.head()
# Out:
#              Name          Website  Organization Id Top Level Category  \
# 0     ClosingLock  closinglock.com        223865172                NaN
# 1   Daloopa, Inc.      daloopa.com        284044302      IT Management
# 2   Daloopa, Inc.      daloopa.com        284044302      IT Management
# 3         UpSmith      upsmith.com        283999461                NaN
# 4  Equal Ventures         equal.vc        160422940                NaN
#
#   Secondary Category  Employee Count  \
# 0                NaN              21
# 1    Data Extraction             226
# 2    Data Extraction             226
# 3                NaN              11
# 4                NaN               5
#
#                                          Description  \
# 0  Closinglock is a company that provides wire tr...
# 1  Discover how the power of over 100 AI algorith...
# 2  Discover how the power of over 100 AI algorith...
# 3                   Transforming the future of work.
# 4  Equal Ventures is a venture capital firm that ...
#
#                               Sourcscrub Description  \
# 0                                                NaN
# 1  Daloopa, Inc. is the only AI solution for inve...
# 2  Daloopa, Inc. is the only AI solution for inve...
# 3  UpSmith, Inc. is a provider of a skilled labor...
# 4                                                NaN
#
#                                        Description.1
# 0         Real Estate Wire Fraud Prevention Solution
# 1      AI-driven enterprise data that can be trusted
# 2      AI-driven enterprise data that can be trusted
# 3  Significantly enhancing lives by giving people...
# 4                                                NaN

# %%
data.info() # check the data type and missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56376 entries, 0 to 56375
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    56376 non-null  object
#  1   Website                 56376 non-null  object
#  2   Organization Id         56376 non-null  int64
#  3   Top Level Category      51602 non-null  object
#  4   Secondary Category      51602 non-null  object
#  5   Employee Count          56376 non-null  int64
#  6   Description             55138 non-null  object
#  7   Sourcscrub Description  56073 non-null  object
#  8   Description.1           39389 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 3.9+ MB

# %%
# checks the number of rows and columns of the data
data.shape
# Out:
# (56376, 9)

# %%
data.describe() # check the summary statistics of the data
# Out:
#        Organization Id  Employee Count
# count     5.637600e+04    56376.000000
# mean      2.872602e+08      571.954608
# std       2.109021e+07     9012.273009
# min       1.514169e+06        1.000000
# 25%       2.881822e+08        4.000000
# 50%       2.904896e+08       20.000000
# 75%       2.914178e+08       75.000000
# max       2.945478e+08   829808.000000

# %%
data.describe(include='object')
# Out:
#           Name      Website Top Level Category Secondary Category  \
# count    56376        56376              51602              51602
# unique   55781        55767               1363               5141
# top     Cortex  avalara.com  Vertical Industry  Talent Management
# freq         6            4              13905               1819
#
#                          Description  \
# count                          55138
# unique                         54996
# top     This domain may be for sale!
# freq                               9
#
#                                    Sourcscrub Description  \
# count                                               56073
# unique                                              55711
# top     Asana, Inc. is a software company that develop...
# freq                                                    4
#
#                                             Description.1
# count                                               39389
# unique                                              39273
# top     Dental Treatment Planning Presentation Softwar...
# freq                                                    3

# %%
# get the column names
data.columns
# Out:
# Index(['Name', 'Website', 'Organization Id', 'Top Level Category',
#        'Secondary Category', 'Employee Count', 'Description',
#        'Sourcscrub Description', 'Description.1'],
#       dtype='object')

# %%
# check for missing values
data.isnull().sum()
# Out:
# Name                          0
# Website                       0
# Organization Id               0
# Top Level Category         4774
# Secondary Category         4774
# Employee Count                0
# Description                1238
# Sourcscrub Description      303
# Description.1             16987
# dtype: int64

# %%
data[data.isnull().any(axis=1)] # check the rows with missing values
# Out:
#                              Name                Website  Organization Id  \
# 0                     ClosingLock        closinglock.com        223865172
# 3                         UpSmith            upsmith.com        283999461
# 4                  Equal Ventures               equal.vc        160422940
# 6             Sadie Blue Software  sadiebluesoftware.com        224638688
# 7                        QuikData           quikdata.com        289080423
# ...                           ...                    ...              ...
# 56352  CannGen Insurance Services         canngenins.com        282401082
# 56356                         CMX               cmx1.com        282401304
# 56364                      Strava             strava.com        282423306
# 56367              Too Good To Go        toogoodtogo.com        282401416
# 56373                   Chess.com              chess.com        282400824
#
#       Top Level Category Secondary Category  Employee Count  \
# 0                    NaN                NaN              21
# 3                    NaN                NaN              11
# 4                    NaN                NaN               5
# 6                    NaN                NaN               5
# 7                    NaN                NaN               7
# ...                  ...                ...             ...
# 56352                NaN                NaN              42
# 56356                NaN                NaN              80
# 56364                NaN                NaN             488
# 56367                NaN                NaN            1428
# 56373                NaN                NaN             737
#
#                                              Description  \
# 0      Closinglock is a company that provides wire tr...
# 3                       Transforming the future of work.
# 4      Equal Ventures is a venture capital firm that ...
# 6      Sadie Blue Software is the maker of Agility Bl...
# 7      QuikData | Simply Powerful eDiscovery: Easy eD...
# ...                                                  ...
# 56352  CannGen Insurance Services, LLC is a leading p...
# 56356  CMX is a platform that helps businesses achiev...
# 56364  Strava is an American internet service for tra...
# 56367  The app that lets you rescue delicious food fr...
# 56373  Chess.com is the premier online chess communit...
#
#                                   Sourcscrub Description  \
# 0                                                    NaN
# 3      UpSmith, Inc. is a provider of a skilled labor...
# 4                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# ...                                                  ...
# 56352  CannGen Insurance Services, LLC offers indepen...
# 56356  Compliancemetrix, Inc. (CMX) is a provider of ...
# 56364  Strava, Inc. is an online network where runner...
# 56367  Too Good To Go ApS (TGTG) is an environmental ...
# 56373  Chess.com, LLC is an online community for ches...
#
#                                            Description.1
# 0             Real Estate Wire Fraud Prevention Solution
# 3      Significantly enhancing lives by giving people...
# 4                                                    NaN
# 6                           All your work, under control
# 7                                                    NaN
# ...                                                  ...
# 56352                                                NaN
# 56356                                                NaN
# 56364  Online network connecting the global community...
# 56367  App that offers a solution to sellers and indi...
# 56373                               Playing chess online
#
# [20265 rows x 9 columns]

# %%
# check for duplicates
duplicate_data = data.duplicated()
print(duplicate_data.sum())
# Out:
# 158

# %% [markdown]
# # Data Cleaning

# %%
# rows with missing description in all 3 columns
nan_descriptions = data[data[['Description', 'Sourcscrub Description', 'Description.1']].isnull().all(axis=1)]
nan_descriptions
# Out:
# Empty DataFrame
# Columns: [Name, Website, Organization Id, Top Level Category, Secondary Category, Employee Count, Description, Sourcscrub Description, Description.1]
# Index: []

# %%
# drop rows with no description
data.drop(nan_descriptions.index, inplace=True)

# fill NaN values with unknown
data['Top Level Category'] = data['Top Level Category'].fillna('Unknown')
data['Secondary Category'] = data['Secondary Category'].fillna('Unknown')
data['Description'] = data['Description'].fillna('No Description')
data['Sourcscrub Description'] = data['Sourcscrub Description'].fillna('No Description')
data['Description.1'] = data['Description.1'].fillna('No Description')
data.head()
# Out:
#              Name          Website  Organization Id Top Level Category  \
# 0     ClosingLock  closinglock.com        223865172            Unknown
# 1   Daloopa, Inc.      daloopa.com        284044302      IT Management
# 2   Daloopa, Inc.      daloopa.com        284044302      IT Management
# 3         UpSmith      upsmith.com        283999461            Unknown
# 4  Equal Ventures         equal.vc        160422940            Unknown
#
#   Secondary Category  Employee Count  \
# 0            Unknown              21
# 1    Data Extraction             226
# 2    Data Extraction             226
# 3            Unknown              11
# 4            Unknown               5
#
#                                          Description  \
# 0  Closinglock is a company that provides wire tr...
# 1  Discover how the power of over 100 AI algorith...
# 2  Discover how the power of over 100 AI algorith...
# 3                   Transforming the future of work.
# 4  Equal Ventures is a venture capital firm that ...
#
#                               Sourcscrub Description  \
# 0                                     No Description
# 1  Daloopa, Inc. is the only AI solution for inve...
# 2  Daloopa, Inc. is the only AI solution for inve...
# 3  UpSmith, Inc. is a provider of a skilled labor...
# 4                                     No Description
#
#                                        Description.1
# 0         Real Estate Wire Fraud Prevention Solution
# 1      AI-driven enterprise data that can be trusted
# 2      AI-driven enterprise data that can be trusted
# 3  Significantly enhancing lives by giving people...
# 4                                     No Description

# %%
# remove duplicates
data.drop_duplicates(inplace=True)
print(data.duplicated().sum()) # should be zero
# Out:
# 0

# %%
# rows with same organization id
duplicates = data[data.duplicated(subset=['Name', 'Website'], keep=False)]
print(duplicates)
# Out:
#                          Name          Website  Organization Id  \
# 5825                    EBANX        ebanx.com        291589887
# 44476              Hospitable   hospitable.com        289332430
# 44478              Hospitable   hospitable.com        291587302
# 45253        Trade Ideas, LLC  trade-ideas.com        283119238
# 45388  Yoxel, LLC dba Aurinko       aurinko.io        287719430
# 45440            Level Access  levelaccess.com        288618696
# 45973        Trade Ideas, LLC  trade-ideas.com        288325851
# 47091  Yoxel, LLC dba Aurinko       aurinko.io        287719477
# 48116                   EBANX        ebanx.com        283480909
# 51113            Level Access  levelaccess.com        286579384
# 55008          Less Paper Co.  lesspaperco.com        283658716
# 55172          Less Paper Co.  lesspaperco.com        282408432
#
#        Top Level Category                          Secondary Category  \
# 5825             Commerce                                     Payment
# 44476   Vertical Industry                                 Real Estate
# 44478             Unknown                                     Unknown
# 45253   Vertical Industry                          Financial Services
# 45388             Unknown                                     Unknown
# 45440  Content Management                           Web Accessibility
# 45973             Unknown                                     Unknown
# 47091             Unknown                                     Unknown
# 48116            Commerce                                     Payment
# 51113  Content Management                           Web Accessibility
# 55008             Unknown                                     Unknown
# 55172    Customer Service  Field Service Management; Customer Service
#
#        Employee Count                                        Description  \
# 5825              712  EBANX is an integrated International financial...
# 44476              40                                     No Description
# 44478              49  Vacation Rental Software Hospitable.com (Smart...
# 45253              32  Trade Ideas is an AI-driven stock scanning and...
# 45388               8  Unlock Relationship Management Insights with A...
# 45440             451  Level Access is a company that offers a comple...
# 45973              34                                     No Description
# 47091               7                                     No Description
# 48116             735  EBANX Payments help global merchants grow expo...
# 51113             451  Learn how the eSSENTIAL Accessibility platform...
# 55008               2  Less Paper Co. provides custom built Work Orde...
# 55172               2                                     No Description
#
#                                   Sourcscrub Description  \
# 5825   EBANX, Ltda. is a financial services business ...
# 44476  Hospitable, Inc. is a company that operates in...
# 44478  Hospitable, Inc. is a software company. It dev...
# 45253  Trade Ideas, LLC is a software development com...
# 45388  Yoxel, LLC doing business as Aurinko, Inc. is ...
# 45440  Level Access Holdings, Inc. is a company that ...
# 45973  Trade Ideas, LLC develops and provides artific...
# 47091  Yoxel, LLC doing business as Aurinko, Inc. is ...
# 48116  EBANX, Ltda. is a financial services business ...
# 51113  Level Access Holdings, Inc. is a company that ...
# 55008  Less Paper Co. creates custom paperless work o...
# 55172  Less Paper Co. creates custom paperless work o...
#
#                                            Description.1  \
# 5825   Payment solutions for global companies to sell...
# 44476                                     No Description
# 44478  The leading solution for short term rental aut...
# 45253  Idea generation technology and real-time risk ...
# 45388                                     No Description
# 45440  Levelaccess.com: Digital Accessibility, Web Ac...
# 45973                                     No Description
# 47091                                     No Description
# 48116  Payment solutions for global companies to sell...
# 51113  A business that provides web accessibility com...
# 55008                                     No Description
# 55172                                     No Description
#
#                                      Unified Description
# 5825   EBANX is an integrated International financial...
# 44476   Hospitable, Inc. is a company that operates i...
# 44478  Vacation Rental Software Hospitable.com (Smart...
# 45253  Trade Ideas is an AI-driven stock scanning and...
# 45388  Unlock Relationship Management Insights with A...
# 45440  Level Access is a company that offers a comple...
# 45973   Trade Ideas, LLC develops and provides artifi...
# 47091   Yoxel, LLC doing business as Aurinko, Inc. is...
# 48116  EBANX Payments help global merchants grow expo...
# 51113  Learn how the eSSENTIAL Accessibility platform...
# 55008  Less Paper Co. provides custom built Work Orde...
# 55172   Less Paper Co. creates custom paperless work ...

# %%
filtered_data = data[data['Top Level Category'] == 'Unknown'] | (data['Secondary Category'] == 'Unknown')
print(filtered_data)

# %% [markdown]
# # Feature Engineering

# %%
# changing the data type of the columns
data['Top Level Category'] = data['Top Level Category'].astype('category') # change to category data type
data['Secondary Category'] = data['Secondary Category'].astype('category') # change to category data type
print(data.dtypes)
# Out:
# Name                        object
# Website                     object
# Organization Id              int64
# Top Level Category        category
# Secondary Category        category
# Employee Count               int64
# Description                 object
# Sourcscrub Description      object
# Description.1               object
# dtype: object

# %%
# adding a unified description column
data['Unified Description'] = data['Description'] + ' ' + data['Sourcscrub Description'] + ' ' + data['Description.1']
print(data['Unified Description'])
# Out:
# 0        Closinglock is a company that provides wire tr...
# 1        Discover how the power of over 100 AI algorith...
# 3        Transforming the future of work. UpSmith, Inc....
# 4        Equal Ventures is a venture capital firm that ...
# 5        AutoLeadStar is automotive's first and leading...
#                                ...
# 56371    North American Bancard is a payments technolog...
# 56372    Datavant is a company that connects the larges...
# 56373    Chess.com is the premier online chess communit...
# 56374    Dutchie is a leading technology partner for ca...
# 56375    Kajabi is an all-in-one knowledge commerce pla...
# Name: Unified Description, Length: 56214, dtype: object

# %%
# remove no decription from the unified description column
data['Unified Description'] = data['Description'].replace('No Description', '') + ' ' + data['Sourcscrub Description'].replace('No Description', '') + ' ' + data['Description.1'].replace('No Description', '')
print(data['Unified Description'])
# Out:
# 0        Closinglock is a company that provides wire tr...
# 1        Discover how the power of over 100 AI algorith...
# 3        Transforming the future of work. UpSmith, Inc....
# 4        Equal Ventures is a venture capital firm that ...
# 5        AutoLeadStar is automotive's first and leading...
#                                ...
# 56371    North American Bancard is a payments technolog...
# 56372    Datavant is a company that connects the larges...
# 56373    Chess.com is the premier online chess communit...
# 56374    Dutchie is a leading technology partner for ca...
# 56375    Kajabi is an all-in-one knowledge commerce pla...
# Name: Unified Description, Length: 56214, dtype: object
